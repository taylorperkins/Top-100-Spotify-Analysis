# %%
import os
import json
import csv

# %%
beats_files = os.listdir('../audio_analysis/beats/')

# %%
len(beats_files)
# Out:
# 5780

# %%
beats_f = open('../audio_analysis/beats/{}'.format(beats_files[0]))
beats_content = json.loads(beats_f.read())

# %%
beats_content
# Out:
# [{'confidence': 0.839, 'duration': 0.72991, 'start': 1.06828},
#  {'confidence': 0.821, 'duration': 0.73733, 'start': 1.79819},
#  {'confidence': 0.425, 'duration': 0.75079, 'start': 2.53552},
#  {'confidence': 0.689, 'duration': 0.75199, 'start': 3.28631},
#  {'confidence': 0.455, 'duration': 0.74715, 'start': 4.03829},
#  {'confidence': 0.271, 'duration': 0.75213, 'start': 4.78545},
#  {'confidence': 0.156, 'duration': 0.75546, 'start': 5.53758},
#  {'confidence': 0.548, 'duration': 0.75447, 'start': 6.29303},
#  {'confidence': 0.615, 'duration': 0.75249, 'start': 7.04751},
#  {'confidence': 0.56, 'duration': 0.74786, 'start': 7.8},
#  {'confidence': 0.359, 'duration': 0.74587, 'start': 8.54785},
#  {'confidence': 0.764, 'duration': 0.75117, 'start': 9.29372},
#  {'confidence': 0.817, 'duration': 0.74785, 'start': 10.04489},
#  {'confidence': 0.704, 'duration': 0.74419, 'start': 10.79274},
#  {'confidence': 0.627, 'duration': 0.74848, 'start': 11.53693},
# ...

# %%
wrong_beats_type = list()
full_beats = list()

# %%
for ind, beat_file in enumerate(beats_files):
    song_id = beat_file.split(".")[0]
    
    if ind % 50 == 0:
        print(ind)
    
    beat_f = open('../audio_analysis/beats/{}'.format(beat_file))
    beat_content = json.loads(beat_f.read())
    beat_f.close()
    
    if isinstance(beat_content, list):
        for beat in beat_content:
            beat['id'] = song_id
    else:
        wrong_bar_type.append(beat_file)
        
    full_beats.extend(beat_content)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750

# %%
wrong_beats_type
# Out:
# []

# %%
full_beats[0]
# Out:
# {'confidence': 0.839,
#  'duration': 0.72991,
#  'id': '003VWU5LKbDkXTqpLQuID1',
#  'start': 1.06828}

# %%
with open('../audio_analysis/beats.csv', 'w') as csvfile:
    fieldnames = ['id', 'confidence', 'start', 'duration']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(full_beats)
    
    csvfile.close()
